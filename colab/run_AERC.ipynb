# %% [markdown]
# <a href="https://colab.research.google.com/github/geozunac3536-jpg/TCDS_CENAPRED_COLLAP_REPO/blob/main/colab/run_AERC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
REPO_OWNER = "geozunac3536-jpg"
REPO_NAME  = "TCDS_CENAPRED_COLLAP_REPO"
BRANCH     = "main"

RAW_BASE = f"https://raw.githubusercontent.com/{REPO_OWNER}/{REPO_NAME}/{BRANCH}"
print("Repositorio:", RAW_BASE)
# Out:
# Repositorio: https://raw.githubusercontent.com/geozunac3536-jpg/TCDS_CENAPRED_COLLAP_REPO/main

# %%
# !pip -q install -r {RAW_BASE}/requirements.txt

# %%
# !wget -q {RAW_BASE}/code/code.py -O code.py
# !chmod +x code.py

# %%
# !python3 code.py --help
# Out:
# usage: code.py [-h] [--manual-csv MANUAL_CSV] [--event EVENT] [--net NET]
#                [--sta STA] [--loc LOC] [--cha CHA] [--out OUT]
#                [--viz-out VIZ_OUT] [--pre PRE] [--post POST] [--win WIN]
#                [--step STEP]
#
# options:
#   -h, --help            show this help message and exit
#   --manual-csv MANUAL_CSV
#   --event EVENT
#   --net NET
#   --sta STA
#   --loc LOC
#   --cha CHA
#   --out OUT
#   --viz-out VIZ_OUT
#   --pre PRE
#   --post POST
#   --win WIN
#   --step STEP
