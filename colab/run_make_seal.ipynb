# %% [markdown]
# <a href="https://colab.research.google.com/github/geozunac3536-jpg/TCDS_CENAPRED_COLLAP_REPO/blob/main/colab/run_make_seal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
REPO_OWNER = "geozunac3536-jpg"
REPO_NAME  = "TCDS_CENAPRED_COLLAP_REPO"
BRANCH     = "main"

RAW_BASE = f"https://raw.githubusercontent.com/{REPO_OWNER}/{REPO_NAME}/{BRANCH}"
print("Repositorio:", RAW_BASE)
# Out:
# Repositorio: https://raw.githubusercontent.com/geozunac3536-jpg/TCDS_CENAPRED_COLLAP_REPO/main

# %%
# !wget -q {RAW_BASE}/tools/make_seal.py -O make_seal.py
# !chmod +x make_seal.py

# %%
# !python3 make_seal.py --help

# %%
# 1) Sube tu archivo al panel izquierdo (Files) de Colab, por ejemplo: result.json
# 2) Ejecuta (descomenta y ajusta el nombre):

# !python3 make_seal.py /content/result.json

print("Listo. Sube el archivo y descomenta el comando para generar el sello.")
# Out:
# Listo. Sube el archivo y descomenta el comando para generar el sello.
