# %% [markdown]
# <a href="https://colab.research.google.com/github/geozunac3536-jpg/TCDS_CENAPRED_COLLAP_REPO/blob/main/colab/run_verify_seal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
REPO_OWNER = "geozunac3536-jpg"
REPO_NAME  = "TCDS_CENAPRED_COLLAP_REPO"
BRANCH     = "main"

RAW_BASE = f"https://raw.githubusercontent.com/{REPO_OWNER}/{REPO_NAME}/{BRANCH}"
print("Repositorio:", RAW_BASE)
# Out:
# Repositorio: https://raw.githubusercontent.com/geozunac3536-jpg/TCDS_CENAPRED_COLLAP_REPO/main

# %%
# !wget -q {RAW_BASE}/tools/verify_seal.py -O verify_seal.py
# !chmod +x verify_seal.py

# %%
# !python3 verify_seal.py --help

# %%
# Caso A (si verify_seal espera archivo + archivo hash):
# 1) Sube ambos a Colab (Files), por ejemplo:
#    - result.json
#    - result.json.sha256
# 2) Ejecuta (descomenta):
#
# !python3 verify_seal.py /content/result.json /content/result.json.sha256

# Caso B (si verify_seal espera archivo + hash en texto):
# !python3 verify_seal.py /content/result.json "<PEGAR_SHA256_AQUI>"

print("Listo. Sube el archivo y su hash, y descomenta el comando correspondiente.")
# Out:
# Listo. Sube el archivo y su hash, y descomenta el comando correspondiente.
